# %% [markdown]
# # Chapter 4- Practical Data Visualisation
#
# ## Segment 3- Creating labels and annotations

# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

import matplotlib.pyplot as plt
from pylab import rcParams

# %%
# %matplotlib inline
rcParams['figure.figsize']= 8,4

# %% [markdown]
# ### Labelling plot features
# The functional method

# %%
x = range(1,10)
y=[1,2,3,4,.5,4,3,2,1 ]

plt.bar(x,y)
plt.xlabel('Your x-axis label')
plt.ylabel('Your y-axis label')
# Out:
# Text(0, 0.5, 'Your y-axis label')

# %%
z = [1,2,3,4,0.5]
veh_type = ['bicycle', 'motorbike', 'car', 'van', 'stroller' ]
plt.pie(z, labels=veh_type)
plt.show()

# %%
address = 'C:/Users/imran/OneDrive/Documents/GitHub/pythonLinkedIn/pythonWithLinkedIn/DS Essential Training 1/Data/mtcars.csv'

cars = pd.read_csv(address)

cars.columns = ['car_names', 'mpg', 'cyl', 'disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am', 'gear', 'carb' ]


mpg = cars.mpg

fig = plt.figure()

ax = fig.add_axes([.1,.1,1,1])
mpg.plot()

ax.set_xticks(range(32))
ax.set_xticklabels(cars.car_names, rotation=60, fontsize='medium')
ax.set_title('Miles per gallon of Cars in mtcars Dataset')
ax.set_xlabel('car names')
ax.set_ylabel('miles per gallon')
# Out:
# Text(0, 0.5, 'miles per gallon')

# %% [markdown]
# ### Adding a legend to your plot
#
# The functional method

# %%
plt.pie(z)
plt.legend(veh_type, loc='best')
plt.show()

# %% [markdown]
# The Object-oriented method

# %%
fig = plt.figure()

ax = fig.add_axes([.1,.1,1,1])

mpg.plot()

ax.set_xticks(range(32))
ax.set_xticklabels(cars.car_names, rotation=60, fontsize='medium')
ax.set_title('Miles per gallon of Cars in mtcars Dataset')

ax.set_xlabel('car names')
ax.set_ylabel('miles per gallon')
ax.legend(loc='best')

# %% [markdown]
# ### Annotating your plot

# %%
mpg.max()
# Out:
# 33.9

# %%
fig = plt.figure()

ax = fig.add_axes([.1,.1,1,1])

mpg.plot()

ax.set_xticks(range(32))
ax.set_xticklabels(cars.car_names, rotation=60, fontsize='medium')
ax.set_title('Miles per gallon of Cars in mtcars Dataset')

ax.set_xlabel('car names')
ax.set_ylabel('miles per gallon')
ax.legend(loc='best')
ax.set_ylim([0,45])
ax.annotate('Totyota Corolla', xy=(19,33.9), xytext=(21,25), 
            arrowprops=dict(facecolor='black', shrink=0.05))
# Out:
# Text(21, 25, 'Totyota Corolla')
