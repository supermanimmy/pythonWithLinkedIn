# %%
40 +2
# Out:
# 42

# %%
import numpy as np

# %%
print(Out[1])
# Out:
# 42

# %%
x = Out[1]

# %%
x
# Out:
# 42

# %%
np.sin(90)
# Out:
# 0.8939966636005579

# %%
np.sin?

# %%
np.any??

# %%
# Magic commands

#current working directory
# %pwd
# Out:
# 'C:\\Users\\imran\\OneDrive\\Documents\\GitHub\\pythonLinkedIn\\pythonWithLinkedIn\\Python Scientific Stack'

# %%
# %%time
for i in range(5):
    print(np.sin(6))
    
    
# 996 µs = 996 microsecond = 1 millonth of a second
# Out:
# -0.27941549819892586
# -0.27941549819892586
# -0.27941549819892586
# -0.27941549819892586
# -0.27941549819892586
# Wall time: 996 µs

# %%
# %magic

# %%
# %timeit range(1000)
# Out:
# 201 ns ± 6.55 ns per loop (mean ± std. dev. of 7 runs, 10000000 loops each)

# %%
# %%timeit x = 'hello'
print(x)
# Out:
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# ...

# %%
alias parts echo first %s second %s

# %%
# %parts A B
# Out:
# first A second B

# %% [markdown]
# * list
# * of
# * items
#
# # Head 1
# ## Head 2
# ### Head 3
# #### Head 4
#
# For Website links:
#
# [Pandas] (http://pandas.pydata.org) is awesome.
#
# For images:
#
# ![]  (https://ggsc.s3.amazonaws.com/images/made/images/uploads/Jan_and_Maisie_200_266_int_c1-1x.jpg)
#
#
# For maths in Latex ( check out The Not So Short Introduction to Latex 2e book)
#
# Euler's identity is $e^{i\pi}+1=0$
